# %%
import numpy as np
import pandas as pd
import sklearn
import gc
import functions
import scipy

# %%
blood_atlas_colours = pd.read_csv('/Users/pwangel/Atlas/data/imac_atlas_colours.tsv', sep='\t').set_index('Sample Source')
blood_atlas_colours = {key:value[0] for key, value in zip(blood_atlas_colours.index.values, blood_atlas_colours.values)}

# %%
data           = pd.read_csv('/Users/pwangel/Downloads/myeloid_atlas_expression_v7.1.tsv', sep='\t', index_col=0)
previous_genes = pd.read_csv('/Users/pwangel/PlotlyWorkspace/combine_data/blood/outputs_for_front_end/iMac_genes.tsv', sep='\t', index_col=0)
annotations    = pd.read_csv('/Users/pwangel/PlotlyWorkspace/combine_data/blood/outputs_for_front_end/iMac_annotations.tsv', sep='\t', index_col=0)

# %%
data = functions.transform_to_percentile(data)

# %%
genes = functions.calculate_platform_dependence(data, annotations)

# %%
functions.plot_pca(data, annotations, genes, labels=['Dataset', 'celltype', 'Platform_Category'], colour_dict=blood_atlas_colours)
# Out:
#                                     type              label
# 0                                Dataset            Dataset
# 1                            granulocyte           celltype
# 2                               monocyte           celltype
# 3                           erythroblast           celltype
# 4                  CD141+ dendritic cell           celltype
# 5                   CD1c+ dendritic cell           celltype
# 6            plasmacytoid dendritic cell           celltype
# 7                             macrophage           celltype
# 8   hematopoietic multipotent progenitor           celltype
# 9              common myeloid progenitor           celltype
# 10       granulocyte monocyte progenitor           celltype
# 11                          promyelocyte           celltype
# 12                             myelocyte           celltype
# 13                         metamyelocyte           celltype
# 14                            neutrophil           celltype
# 15                endothelial progenitor           celltype
# 16                        dendritic cell           celltype
# 17                       proerythroblast           celltype
# 18            common lymphoid progenitor           celltype
# 19                             microglia           celltype
# 20                           erythrocyte           celltype
# 21                          kupffer cell           celltype
# 22                 hemogenic endothelium           celltype
# 23                         hemangioblast           celltype
# 24                           Illumina V2  Platform_Category
# 25                           Illumina V4  Platform_Category
# 26                        HG-U133_Plus_2  Platform_Category
# 27                                RNASeq  Platform_Category
# 28                                HuGene  Platform_Category
# [True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False]
# [False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, False, False, False, False, False]
# [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, True, True, True]
# <div>
#
#
#             <div id="6f16216c-90ad-4718-bbbf-11e728fd89e0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6f16216c-90ad-4718-bbbf-11e728fd89e0")) {
#                     Plotly.newPlot(
#                         '6f16216c-90ad-4718-bbbf-11e728fd89e0',
#                         [{"marker": {"color": [1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 6612.0, 6612.0, 6612.0, 6612.0, 6612.0, 6612.0, 6612.0, 6612.0, 6612.0, 6612.0, 6612.0, 6612.0, 6612.0, 6612.0, 6612.0, 6612.0, 6612.0, 6612.0, 6612.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 6646.0, 7002.0, 7002.0, 7002.0, 7079.0, 7079.0, 7079.0, 7079.0, 7079.0, 7079.0, 7079.0, 7079.0, 7079.0, 7079.0, 7079.0, 7079.0, 7079.0, 7079.0, 7079.0, 7079.0, 7079.0, 7079.0, 7079.0, 7079.0, 7079.0, 7079.0, 7079.0, 7079.0, 7079.0, 7079.0, 7079.0, 7079.0, 7079.0, 7079.0, 7079.0, 7079.0, 7079.0, 6237.0, 6237.0, 6237.0, 6237.0, 6237.0, 6237.0, 6237.0, 6237.0, 6237.0, 6237.0, 6237.0, 6237.0, 6237.0, 6237.0, 6358.0, 6358.0, 6358.0, 6358.0, 6358.0, 6358.0, 6358.0, 6358.0, 6358.0, 6358.0, 6358.0, 6358.0, 6358.0, 6358.0, 6358.0, 6358.0, 6358.0, 6358.0, 6358.0, 6358.0, 6358.0, 6358.0, 6358.0, 6358.0, 6358.0, 6358.0, 6358.0, 6774.0, 6774.0, 6774.0, 6774.0, 6774.0, 6774.0, 6774.0, 6774.0, 6363.0, 6363.0, 6363.0, 6363.0, 6363.0, 6363.0, 6363.0, 6366.0, 6366.0, 6366.0, 6366.0, 6366.0, 6366.0, 6366.0, 6366.0, 6366.0, 6326.0, 6326.0, 6326.0, 6326.0, 6326.0, 6326.0, 6326.0, 6326.0, 6326.0, 6326.0, 6326.0, 6326.0, 6339.0, 6339.0, 6339.0, 6339.0, 6339.0, 6339.0, 6339.0, 6339.0, 6339.0, 6339.0, 6339.0, 6339.0, 6339.0, 6339.0, 6339.0, 6339.0, 6339.0, 6339.0, 6339.0, 6339.0, 6339.0, 6339.0, 6339.0, 6339.0, 6339.0, 6339.0, 6339.0, 6339.0, 6601.0, 6601.0, 6601.0, 6601.0, 6601.0, 6601.0, 6601.0, 6601.0, 6601.0, 6601.0, 6601.0, 6601.0, 6601.0, 6601.0, 6601.0, 7264.0, 7264.0, 7264.0, 7264.0, 7264.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 6741.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7003.0, 7 ...
